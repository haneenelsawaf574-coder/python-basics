# %%
cities=["kSA","Egypt","London","tokyo","paris"]
for city in cities:
 print(city)
# Out:
# kSA
# Egypt
# London
# tokyo
# paris

# %%
numbers=[22,34,65,11,33,7,12]
average=sum(numbers)/len(numbers)
print(f"Average:{average}")
# Out:
# Average:26.285714285714285

# %%
def can_vote(age):
 if age>=18:
  return "can vote"
 else:
  return "cannot vote"
print(can_vote(20))
# Out:
# can vote
