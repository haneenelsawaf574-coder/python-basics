# %%
import pandas as pd

# %%
df = pd.read_csv(
    "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
)

# %% [markdown]
# Does it
# load
# correctly? YES

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# What does
# the data
# look like? The dataset contains passenger information such as age, sex, class, fare, and survival status

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# How many
# passengers?891
# How many
# features?12

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# What
# information
# do we
# have? ('PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# Which are
# numbers?
# Which are
# text?
# - numberes(PassengerId,Survived,Pclass,Age,SibSp,Parch,Fare)
# - text(Name,Sex,Ticket,Cabin,Embarked)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Any
# missing
# values? yes

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# - Age range? 0.420000-80.000000
# - Fare range? 0.000000-512.329200
# - Average? age(29.699118)-fare(32.204208)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# - Which
# columns
# have
# missing
# data? (age-cabin-embarked)
# - How
# many?(177,687,2)

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# - How many
# survived?342
# - died?549
# - What
#  %? (38.38%),(61.62%)

# %%
df['Age'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# Age
# distribution
# pattern? most pasengers are adult(20-40)..children are less (1-10)

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# More males
# or females? males

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# Distribution across
# classes?
# - 1 class 3(491)
# - 2 class 1(216)
# - 3 class 2(184)

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# Did gender
# affect
# survival? yes females was survived much more than males

# %%
df.groupby('Pclass')['Survived'].mean(
)
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# Did class
# affect
# survival? yes First-class passengers had the highest survival rate

# %%
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# How did
# fares
# differ?First-class passengers paid the highest average fare, followed by second class, while third-class passengers paid the lowest fares

# %%
df.boxplot(column='Age',
by='Survived')
# Out:
# <Axes: title={'center': 'Age'}, xlabel='Survived'>

# %% [markdown]
# Did age
# affect
# survival?no

# %%
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# What
# features
# correlate
# with
# survival? pclass(negative correlation),fare(positive correlation)

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Visual
# correlation
# patterns? strong negative correlation between pclass and fare, and a positive correlation between SibSp and Parch.

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# - not survived: more than 500
# - survived: between 300-400

# %%
df['Age'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# The age distribution shows that most passengers were young adults between 20-40

# %%
df.boxplot(column='Fare', by='Pclass')
# Out:
# <Axes: title={'center': 'Fare'}, xlabel='Pclass'>

# %%
df.plot.scatter(x='Age', y='Fare')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# no strong relationship between age and fare.

# %%
df['Pclass'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# most passengers belonged to the third class

# %%
df['Survived'].mean() * 100
# Out:
# np.float64(38.38383838383838)

# %% [markdown]
# What was the overall
# survival rate?38.38383838383838

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# Did more males or
# females survive? females

# %%
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# Which passenger class
# had highest survival? first class

# %%
df['Age'].min(), df['Age'].max()
# Out:
# (0.42, 80.0)

# %% [markdown]
# What was the age range
# of passengers? from 0.42 to 80.0

# %%
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# What was the average
# fare by class? first class had higher fare then second class then the last

# %%
df[df['Age'] < 18]['Survived'].sum()
# Out:
# np.int64(61)

# %% [markdown]
# How many children (age
# < 18) survived? 61

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# Which port had most
# passengers? S

# %%
df['FamilySize'] = df['SibSp'] + df['Parch']

# %%
df.groupby('FamilySize')['Survived'].mean()
# Out:
# FamilySize
# 0     0.303538
# 1     0.552795
# 2     0.578431
# 3     0.724138
# 4     0.200000
# 5     0.136364
# 6     0.333333
# 7     0.000000
# 10    0.000000
# Name: Survived, dtype: float64

# %% [markdown]
# Did people with family
# survive more?Passengers with small family sizes showed better survival chances

# %%
df['Age'].isnull().sum() / len(df) * 100
# Out:
# np.float64(19.865319865319865)

# %% [markdown]
# What % of data is
# missing for Age? 19.86

# %% [markdown]
# What insights can you
# draw?
# - First-class passengers paid the highest average fare, followed by second class, while third-class passengers paid the lowest fares
# - females was survived much more than males
# - First-class passengers had the highest survival rate
# - Passengers with small family sizes showed better survival chances
